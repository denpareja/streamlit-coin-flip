# %%
import sys
print(sys.executable)
print("Hola desde mi_entorno 🚀")
# Out:
# c:\Users\Denisse Pareja\anaconda3\envs\mi_entorno\python.exe
# Hola desde mi_entorno 🚀

# %%
pip install notebook ipykernel matplotlib numpy
# Out:
# ...
#    ---------------------------------------- 0.0/14.3 MB ? eta -:--:--
#    ----------- ---------------------------- 4.2/14.3 MB 23.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 8.4/14.3 MB 20.5 MB/s eta 0:00:01
#    -------------------------------- ------- 11.5/14.3 MB 22.4 MB/s eta 0:00:01
#    ---------------------------------------- 14.3/14.3 MB 19.4 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    --------------- ------------------------ 4.7/12.3 MB 24.0 MB/s eta 0:00:01
#    -------------------------------- ------- 10.0/12.3 MB 25.0 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 22.3 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------- ----------- 5.8/8.1 MB 27.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 22.5 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.rand(50)
y = np.random.rand(50)

plt.scatter(x, y, c='blue', edgecolors='k', alpha=0.7)
plt.title("Gráfico de dispersión en VS Code 🎨")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
# Out:
# c:\Users\Denisse Pareja\anaconda3\envs\mi_entorno\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127912 (\N{ARTIST PALETTE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
